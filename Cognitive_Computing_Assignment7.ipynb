# %% [markdown]
# <a href="https://colab.research.google.com/github/akashgoyal-20/Cognitive-Computing-Assignments/blob/main/Cognitive_Computing_Assignment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 1:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
np.random.seed(102317024)
sales_data=np.random.randint(1000,5001,size=(12,4))
months=['Jan','Feb','Mar','Apr','May','June','July','Aug','Sept','Oct','Nov','Dec']
df=pd.DataFrame(sales_data,columns=['Electronics','Clothing','Home & Kitchen','Sports'],index=months)

print(df.head())
print(df.describe())
print(df.sum(axis=0))
sum_month=list(df.sum(axis=1))
print(sum_month)
print(df.diff().mean())
df['Total Sales']=df.sum(axis=1)
growth_rate=[None]
for i in range(1,len(df)):
  prev=df['Total Sales'].iloc[i-1]
  curr=df['Total Sales'].iloc[i]
  change=((curr-prev)/prev)*100
  growth_rate.append(change)
df['Growth Rate']=growth_rate

roll_number=102317024
if(roll_number%2==0):
  df['Electronics']=df['Electronics']-df['Electronics']*0.1
else:
  df['Clothing']=df['Clothing']-df['Clothing']*0.15

plt.plot(df.index, df['Electronics'], marker='o', label="Electronics")
plt.plot(df.index, df['Clothing'], marker='o', label="Clothing")
plt.plot(df.index, df['Home & Kitchen'], marker='o', label="Home & Kitchen")
plt.plot(df.index, df['Sports'], marker='o', label="Sports")
plt.title("Monthly Sales Trends")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend()
plt.grid()
plt.show()

df.boxplot(column=["Electronics", "Clothing", "Home & Kitchen", "Sports"])
plt.title("Sales Distribution per Category")
plt.grid()
plt.show()
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         2039      4061            4997    4690
# Feb         3370      4527            4127    2684
# Mar         1728      4952            3316    4167
# Apr         2669      1595            2781    1161
# May         2982      3505            1906    4971
#        Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   3132.666667  3530.666667     3351.250000  2665.250000
# std    1108.540427  1000.333429     1057.182114  1421.054674
# min    1353.000000  1595.000000     1852.000000  1161.000000
# 25%    2489.750000  3446.750000     2761.250000  1661.000000
# 50%    3176.000000  3635.500000     3084.000000  2114.500000
# 75%    3831.250000  4040.750000     4172.250000  4071.750000
# max    4849.000000  4952.000000     4997.000000  4971.000000
# Electronics       37592
# Clothing          42368
# Home & Kitchen    40215
# Sports            31983
# dtype: int64
# [15787, 14708, 14163, 8206, 13364, 13867, 13012, 7548, 13487, 12329, 13628, 12059]
# Electronics       239.181818
# Clothing          -33.545455
# Home & Kitchen   -285.909091
# Sports           -258.636364
# dtype: float64

# %% [markdown]
# Question 2:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

arr=np.array([[1,-2,3],[-4,5,-6]])
print("Absolute values are:-")
print(np.abs(arr))
print("Percentiles of flattened, column-wise and row-wise are:-")
print(np.percentile(arr,[25,50,75]))
print(np.percentile(arr,[25,50,75],axis=0))
print(np.percentile(arr,[25,50,75],axis=1))
print("Mean of flattened,column-wise and row-wise array are:-")
print(np.mean(arr))
print(np.mean(arr,axis=0))
print(np.mean(arr,axis=1))
print("Median of flattened,column-wise and row-wise array are:-")
print(np.median(arr))
print(np.median(arr,axis=0))
print(np.median(arr,axis=1))
print("Standard Deviation of flattened,column-wise and row-wise array are:-")
print(np.std(arr))
print(np.std(arr,axis=0))
print(np.std(arr,axis=1))
# Out:
# Absolute values are:-
# [[1 2 3]
#  [4 5 6]]
# Percentiles of flattened, column-wise and row-wise are:-
# [-3.5 -0.5  2.5]
# [[-2.75 -0.25 -3.75]
#  [-1.5   1.5  -1.5 ]
#  [-0.25  3.25  0.75]]
# [[-0.5 -5. ]
#  [ 1.  -4. ]
#  [ 2.   0.5]]
# Mean of flattened,column-wise and row-wise array are:-
# -0.5
# [-1.5  1.5 -1.5]
# [ 0.66666667 -1.66666667]
# Median of flattened,column-wise and row-wise array are:-
# -0.5
# [-1.5  1.5 -1.5]
# [ 1. -4.]
# Standard Deviation of flattened,column-wise and row-wise array are:-
# 3.8622100754188224
# [2.5 3.5 4.5]
# [2.05480467 4.78423336]

# %% [markdown]
# Question 3:

# %%
import numpy as np
a=np.array([-1.8,-1.6,-0.5,0.5,1.6,1.8,3])
print("Floor:", np.floor(a))
print("Ceiling:", np.ceil(a))
print("Truncated:", np.trunc(a))
print("Rounded:", np.round(a))
# Out:
# Floor: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded: [-2. -2. -0.  0.  2.  2.  3.]

# %% [markdown]
# Question 4:

# %%
def swap_list_elements(arr,pos1,pos2):
    temp = arr[pos1]
    arr[pos1] = arr[pos2]
    arr[pos2] = temp
    print(f"List after swapping positions {pos1} and {pos2}: {arr}")

my_list = [10,20,30,40,50]
print(f"Original list: {my_list}")
swap_list_elements(my_list,1,3)
# Out:
# Original list: [10, 20, 30, 40, 50]
# List after swapping positions 1 and 3: [10, 40, 30, 20, 50]

# %% [markdown]
# Question 5:

# %%
s = {2, 1, 3, 4, 5}
s_list = list(s)
num = s_list[0]
s_list[0] = s_list[1]
s_list[1] = num
s = set(s_list)
print(s)
# Out:
# {1, 2, 3, 4, 5}
